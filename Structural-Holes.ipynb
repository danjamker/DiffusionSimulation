# %%
# %load_ext autoreload
# %autoreload 2
import networkx as nx
import pandas as pd
from networkx_additional_algorithms import structural_holes
reload(structural_holes)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <module 'networkx_additional_algorithms.structural_holes' from 'networkx_additional_algorithms/structural_holes.pyc'>

# %%
G=nx.read_gpickle("./networks/twitter_geo_network_pagerank.gpickle")

# %%
structural_holes.structural_holes(G)
# Out:
# graph is undirected... setting includeOutLinks to True and includeInLinks to False
# {'EH21': {'C-Density': 0.06185136044538523,
#   'C-Hierarchy': 0.022914172569733188,
#   'C-Index': 0.14603267338295517,
#   'C-Size': 0.061267140367836738},
#  'EH20': {'C-Density': 0.060498219459994805,
#   'C-Hierarchy': 0.026073939572600985,
#   'C-Index': 0.13722022331309247,
#   'C-Size': 0.050648064280496667},
#  'EH23': {'C-Density': 0.09246515434729545,
#   'C-Hierarchy': 0.030520148991585925,
#   'C-Index': 0.22898773812486953,
#   'C-Size': 0.10600243478598814},
#  'EH22': {'C-Density': 0.066536293131900556,
#   'C-Hierarchy': 0.024533792940595801,
#   'C-Index': 0.1821699836523277,
#   'C-Size': 0.091099897579831335},
#  'EH25': {'C-Density': 0.061289942873923427,
#   'C-Hierarchy': 0.029583007933675246,
#   'C-Index': 0.17648719322661321,
#   'C-Size': 0.085614242419014552},
#  'EH24': {'C-Density': 0.080246073603424117,
#   'C-Hierarchy': 0.031563952915415298,
# ...
