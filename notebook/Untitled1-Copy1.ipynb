# %%
# %matplotlib inline

from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.linear_model import LinearRegression
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
from pandas.tools.plotting import scatter_matrix

# %%
import json
from pprint import pprint

df = pd.DataFrame()

# with open('/Users/danielkershaw/PycharmProjects/DiffusionSimulation/output/lr-test/part-00000') as data_file:
with open('/Users/danielkershaw/Downloads/reddit-comment-popularity-3') as data_file:
    for l in data_file:
        try:
            data = json.loads(l)
            dff = pd.read_json(data["vales"])
            dff["range"] = data["D"]
            df = pd.concat((df, dff))
        except:
            pass

# %%
df.index.name = 'date'
df
# Out:
#       activations  range
# date
# 0        0.035714     30
# 1        0.035714     30
# 10       0.107143     30
# 11       0.178571     30
# 12       0.214286     30
# 13       0.214286     30
# 14       0.214286     30
# 15       0.214286     30
# 16       0.321429     30
# 17       0.357143     30
# 18       0.357143     30
# 19       0.464286     30
# 2        0.035714     30
# 20       0.607143     30
# 21       0.607143     30
# 22       0.607143     30
# 23       0.642857     30
# 24       0.750000     30
# 25       0.821429     30
# 26       0.821429     30
# 27       0.892857     30
# 28       0.928571     30
# 29       0.964286     30
# 3        0.035714     30
# 30       1.000000     30
# 4        0.035714     30
# 5        0.071429     30
# 6        0.071429     30
# 7        0.071429     30
# 8        0.071429     30
# ...           ...    ...
# 64       0.475410     90
# 65       0.508197     90
# 66       0.540984     90
# 67       0.688525     90
# 68       0.704918     90
# 69       0.721311     90
# 7        0.016393     90
# 70       0.754098     90
# 71       0.786885     90
# 72       0.786885     90
# 73       0.803279     90
# 74       0.852459     90
# 75       0.885246     90
# 76       0.918033     90
# 77       0.934426     90
# 78       0.983607     90
# 79       1.000000     90
# 8        0.016393     90
# 80       1.000000     90
# 81       1.000000     90
# 82       1.000000     90
# 83       1.000000     90
# 84       1.000000     90
# 85       1.000000     90
# 86       1.000000     90
# 87       1.000000     90
# 88       1.000000     90
# 89       1.000000     90
# 9        0.016393     90
# 90       1.000000     90
#
# [206 rows x 2 columns]

# %%
df.reset_index().pivot(index='date', columns='range', values='activations')[60].plot()

# %%
df.reset_index().pivot(index='date', columns='range', values='activations')
# Out:
# range   7         90
# date
# 0      1.0  0.016393
# 1      1.0  0.016393
# 2      1.0  0.016393
# 3      1.0  0.016393
# 4      1.0  0.016393
# 5      1.0  0.016393
# 6      1.0  0.016393
# 7      1.0  0.016393
# 8      NaN  0.016393
# 9      NaN  0.016393
# 10     NaN  0.016393
# 11     NaN  0.016393
# 12     NaN  0.016393
# 13     NaN  0.016393
# 14     NaN  0.016393
# 15     NaN  0.016393
# 16     NaN  0.016393
# 17     NaN  0.016393
# 18     NaN  0.016393
# 19     NaN  0.016393
# 20     NaN  0.016393
# 21     NaN  0.016393
# 22     NaN  0.016393
# 23     NaN  0.016393
# 24     NaN  0.016393
# 25     NaN  0.016393
# 26     NaN  0.049180
# 27     NaN  0.049180
# 28     NaN  0.065574
# 29     NaN  0.065574
# ...    ...       ...
# 61     NaN  0.393443
# 62     NaN  0.426230
# 63     NaN  0.459016
# 64     NaN  0.475410
# 65     NaN  0.508197
# 66     NaN  0.540984
# 67     NaN  0.688525
# 68     NaN  0.704918
# 69     NaN  0.721311
# 70     NaN  0.754098
# 71     NaN  0.786885
# 72     NaN  0.786885
# 73     NaN  0.803279
# 74     NaN  0.852459
# 75     NaN  0.885246
# 76     NaN  0.918033
# 77     NaN  0.934426
# 78     NaN  0.983607
# 79     NaN  1.000000
# 80     NaN  1.000000
# 81     NaN  1.000000
# 82     NaN  1.000000
# 83     NaN  1.000000
# 84     NaN  1.000000
# 85     NaN  1.000000
# 86     NaN  1.000000
# 87     NaN  1.000000
# 88     NaN  1.000000
# 89     NaN  1.000000
# 90     NaN  1.000000
#
# [91 rows x 2 columns]

# %%
df[(df["popularity"]< 1)].pivot(index='word', columns='timedelta', values='popularity').hist(bins=100, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x119fceb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x110642e10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11c7d3c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119e87350>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11a591610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118f66a10>]], dtype=object)

# %%
scatter_matrix(df[(df["popularity"]< 1)].pivot(index='word', columns='timedelta', values='popularity'), alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11a6afd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11afafe90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11a499610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b40ffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b496490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11b4e1990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b7a3b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b8209d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b88a990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b90b810>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11b970750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b9f25d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b988d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bae3490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bb67310>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11bbc8c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bc4bb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bcafb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bd32ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bd3fe50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11be24950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c04d7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c0b3910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c134790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c19d490>]], dtype=object)

# %%
df[(df["popularity"]< 1)].pivot(index='word', columns='timedelta', values='popularity').plot(kind='scatter',x=90, y=7)

# %%
df[(df["popularity"]==0.5)&(df["timedelta"]==90)]
# Out:
#                                              activations  popularity  \
# 13290  {"1413244800000":0.1666666667,"1413331200000":...         0.5
# 14515  {"1413417600000":0.1,"1413504000000":0.1,"1413...         0.5
# 15250  {"1413072000000":0.25,"1413158400000":0.25,"14...         0.5
# 17375  {"1413331200000":0.25,"1413417600000":0.25,"14...         0.5
# 18300  {"1413158400000":0.1,"1413244800000":0.1,"1413...         0.5
# 19630  {"1411862400000":0.1666666667,"1411948800000":...         0.5
# 22575  {"1412467200000":0.1,"1412553600000":0.1,"1412...         0.5
# 28650  {"1417651200000":0.125,"1417737600000":0.125,"...         0.5
# 3095   {"1412899200000":0.1666666667,"1412985600000":...         0.5
# 32185  {"1411862400000":0.1666666667,"1411948800000":...         0.5
# 34065  {"1412121600000":0.1,"1412208000000":0.1,"1412...         0.5
# 35225  {"1412467200000":0.1,"1412553600000":0.1,"1412...         0.5
# 36765  {"1412812800000":0.25,"1412899200000":0.25,"14...         0.5
# 40340  {"1412294400000":0.1,"1412380800000":0.1,"1412...         0.5
# 4225   {"1411603200000":0.25,"1411689600000":0.25,"14...         0.5
# 44600  {"1412553600000":0.25,"1412640000000":0.25,"14...         0.5
# 47745  {"1412294400000":0.125,"1412380800000":0.125,"...         0.5
# 53160  {"1412899200000":0.1666666667,"1412985600000":...         0.5
# 54790  {"1412985600000":0.25,"1413072000000":0.25,"14...         0.5
# 61715  {"1413158400000":0.0833333333,"1413244800000":...         0.5
# 6835   {"1415923200000":0.1666666667,"1416009600000":...         0.5
# 74880  {"1412121600000":0.1666666667,"1412208000000":...         0.5
# 76105  {"1411776000000":0.1666666667,"1411862400000":...         0.5
# 81845  {"1411776000000":0.125,"1411862400000":0.125,"...         0.5
# 82515  {"1413244800000":0.25,"1413331200000":0.25,"14...         0.5
# 8670   {"1414972800000":0.125,"1415059200000":0.125,"...         0.5
#
#        timedelta          word
# 13290         90      mangeurs
# 14515         90         goosy
# 15250         90       uberpop
# 17375         90         natoo
# 18300         90         lavee
# 19630         90      slimebag
# 22575         90        unlick
# 28650         90  gigismayfair
# 3095          90     intimidad
# 32185         90        bombae
# 34065         90      orijinal
# 35225         90     quisieron
# 36765         90       wannttt
# 40340         90       mandata
# 4225          90        zuccas
# 44600         90         ypuve
# 47745         90       fidarsi
# 53160         90    muhalefete
# 54790         90      homeplus
# 61715         90        wolnej
# 6835          90        delmas
# 74880         90     hairclips
# 76105         90        shruti
# 81845         90         duszy
# 82515         90       netatmo
# 8670          90    extremista
