# %%
# %matplotlib inline

from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.linear_model import LinearRegression
import matplotlib.pylab as plt
import pandas as pd
import numpy as np
from pandas.tools.plotting import scatter_matrix

# %%
import json
from pprint import pprint

df = pd.DataFrame()

# with open('/Users/danielkershaw/PycharmProjects/DiffusionSimulation/output/lr-test/part-00000') as data_file:
with open('/Users/danielkershaw/Downloads/reddit-comment-popularity-7') as data_file:
    for l in data_file:
        try:
            data = json.loads(l)
            dff = pd.read_json(data["vales"])
            dff["range"] = data["D"]
            df = pd.concat((df, dff))
        except:
            pass

# %%
df.index.name = 'date'
df
# Out:
#       activations  range
# date
# 0        0.523287     30
# 1        0.552949     30
# 10       0.698554     30
# 11       0.712632     30
# 12       0.727447     30
# 13       0.742190     30
# 14       0.757824     30
# 15       0.772764     30
# 16       0.787370     30
# 17       0.802716     30
# 18       0.816411     30
# 19       0.830444     30
# 2        0.572888     30
# 20       0.845867     30
# 21       0.862141     30
# 22       0.878123     30
# 23       0.893488     30
# 24       0.908948     30
# 25       0.924036     30
# 26       0.940061     30
# 27       0.956443     30
# 28       0.973721     30
# 29       0.991531     30
# 3        0.589658     30
# 30       1.000000     30
# 4        0.606270     30
# 5        0.622115     30
# 6        0.637806     30
# 7        0.654210     30
# 8        0.669160     30
# ...           ...    ...
# 64       0.784783     90
# 65       0.792762     90
# 66       0.800338     90
# 67       0.807646     90
# 68       0.815210     90
# 69       0.823687     90
# 7        0.354308     90
# 70       0.831674     90
# 71       0.839948     90
# 72       0.847467     90
# 73       0.855468     90
# 74       0.863209     90
# 75       0.871026     90
# 76       0.879169     90
# 77       0.888629     90
# 78       0.897604     90
# 79       0.905865     90
# 8        0.362347     90
# 80       0.914493     90
# 81       0.922636     90
# 82       0.931347     90
# 83       0.940503     90
# 84       0.950583     90
# 85       0.959302     90
# 86       0.968082     90
# 87       0.977339     90
# 88       0.986153     90
# 89       0.995098     90
# 9        0.370376     90
# 90       1.000000     90
#
# [206 rows x 2 columns]

# %%
df.reset_index().pivot(index='date', columns='range', values='activations').plot()

# %%
df.reset_index().pivot(index='date', columns='range', values='activations')
# Out:
# range        7         14        30        60        90
# date
# 0      0.779325  0.673087  0.523287  0.365813  0.279642
# 1      0.828042  0.712705  0.552949  0.387452  0.297242
# 2      0.862183  0.739789  0.572888  0.401840  0.308659
# 3      0.892413  0.762889  0.589658  0.413626  0.318164
# 4      0.923057  0.786268  0.606270  0.425474  0.327618
# 5      0.953303  0.808649  0.622115  0.436689  0.336641
# 6      0.983680  0.831087  0.637806  0.447644  0.345213
# 7      1.000000  0.854837  0.654210  0.459034  0.354308
# 8           NaN  0.876826  0.669160  0.469281  0.362347
# 9           NaN  0.898540  0.683841  0.479454  0.370376
# 10          NaN  0.920465  0.698554  0.489241  0.378044
# 11          NaN  0.941709  0.712632  0.498677  0.385373
# 12          NaN  0.964581  0.727447  0.508446  0.392821
# 13          NaN  0.987542  0.742190  0.518064  0.400337
# 14          NaN  1.000000  0.757824  0.528387  0.408344
# 15          NaN       NaN  0.772764  0.538222  0.415972
# 16          NaN       NaN  0.787370  0.547764  0.423359
# 17          NaN       NaN  0.802716  0.557471  0.430891
# 18          NaN       NaN  0.816411  0.566095  0.437616
# 19          NaN       NaN  0.830444  0.575102  0.444607
# 20          NaN       NaN  0.845867  0.584708  0.451912
# 21          NaN       NaN  0.862141  0.594997  0.459763
# 22          NaN       NaN  0.878123  0.605012  0.467388
# 23          NaN       NaN  0.893488  0.614411  0.474488
# 24          NaN       NaN  0.908948  0.623830  0.481590
# 25          NaN       NaN  0.924036  0.632796  0.488527
# 26          NaN       NaN  0.940061  0.642509  0.495730
# 27          NaN       NaN  0.956443  0.652452  0.503258
# 28          NaN       NaN  0.973721  0.662574  0.511018
# 29          NaN       NaN  0.991531  0.672932  0.518893
# ...         ...       ...       ...       ...       ...
# 61          NaN       NaN       NaN       NaN  0.760904
# 62          NaN       NaN       NaN       NaN  0.768465
# 63          NaN       NaN       NaN       NaN  0.776440
# 64          NaN       NaN       NaN       NaN  0.784783
# 65          NaN       NaN       NaN       NaN  0.792762
# 66          NaN       NaN       NaN       NaN  0.800338
# 67          NaN       NaN       NaN       NaN  0.807646
# 68          NaN       NaN       NaN       NaN  0.815210
# 69          NaN       NaN       NaN       NaN  0.823687
# 70          NaN       NaN       NaN       NaN  0.831674
# 71          NaN       NaN       NaN       NaN  0.839948
# 72          NaN       NaN       NaN       NaN  0.847467
# 73          NaN       NaN       NaN       NaN  0.855468
# 74          NaN       NaN       NaN       NaN  0.863209
# 75          NaN       NaN       NaN       NaN  0.871026
# 76          NaN       NaN       NaN       NaN  0.879169
# 77          NaN       NaN       NaN       NaN  0.888629
# 78          NaN       NaN       NaN       NaN  0.897604
# 79          NaN       NaN       NaN       NaN  0.905865
# 80          NaN       NaN       NaN       NaN  0.914493
# 81          NaN       NaN       NaN       NaN  0.922636
# 82          NaN       NaN       NaN       NaN  0.931347
# 83          NaN       NaN       NaN       NaN  0.940503
# 84          NaN       NaN       NaN       NaN  0.950583
# 85          NaN       NaN       NaN       NaN  0.959302
# 86          NaN       NaN       NaN       NaN  0.968082
# 87          NaN       NaN       NaN       NaN  0.977339
# 88          NaN       NaN       NaN       NaN  0.986153
# 89          NaN       NaN       NaN       NaN  0.995098
# 90          NaN       NaN       NaN       NaN  1.000000
#
# [91 rows x 5 columns]

# %%
import json
from pprint import pprint
with open('/Users/danielkershaw/Downloads/part-00004 (4)') as data_file:
    df = pd.read_json(json.load(data_file))

# %%
scatter_matrix(df.pivot(index='word', columns='period', values='activation'), alpha=0.2, figsize=(15, 15), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10e6239d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ce73c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c261fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c164c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c0cda10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10c1e92d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10a1c0650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10bffbd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10bf6c3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10bf017d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10ccd4090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ccadb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ccc5e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10bcbc1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c652390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10bbc97d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c5ded90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c41bd50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b9f9350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ae54c10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10b913d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c17a910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10bb5e850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c0f56d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10c61d3d0>]], dtype=object)

# %%
# df[(df["popularity"]< 1)].pivot(index='word', columns='timedelta', values='popularity').plot(kind='scatter',x=90, y=7)
df.pivot(index='word', columns='period', values='activation').plot(kind='scatter',x=7, y=30, loglog=True)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
dfp = df.pivot(index='word', columns='period', values='activation')
ttt = [7,14,30,60,90]
dfp.columns = ['a', 'b', 'c', 'd', 'e']

fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(25, 25))

for x1 in range(0, len(dfp.columns)):
    for y1 in range(0, len(dfp.columns)):
        results =  smf.ols(dfp.columns[y1]+' ~ '+dfp.columns[x1], dfp).fit()
        intercept, slope = results.params
        r2 = results.rsquared
        x = np.array([min(dfp[dfp.columns[x1]]), max(dfp[dfp.columns[x1]])])
        y = intercept + slope * x
        ax = df.pivot(index='word', columns='period', values='activation').plot(kind='scatter',x=ttt[x1], y=ttt[y1], loglog=True, ax=axes[x1,y1])
        axes[x1,y1].plot(x, y, 'r-')
        x_lims = axes[x1,y1].get_xlim()
        y_lims = axes[x1,y1].get_ylim()
        axes[x1,y1].plot(y_lims, x_lims, 'g-')
